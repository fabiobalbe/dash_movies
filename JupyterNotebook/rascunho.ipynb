# %%
import pandas as pd

# %%
data = pd.read_csv('disney_movies.csv')

data
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
data['release_date'] = pd.to_datetime(data['release_date'])

data['Year'] = pd.to_datetime(data['release_date']).dt.year

data
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  Year
# ...

# %%
data1 = data[data['Year'] >= 2000]

data1.to_csv('update.csv', index=False)

# %%
df = pd.read_csv('update.csv')

df
# Out:
#                       movie_title release_date      genre mpaa_rating  \
# 0            Fantasia 2000 (IMAX)   2000-01-01    Musical           G
# 1                         Gun Shy   2000-02-04     Comedy           R
# 2                The Tigger Movie   2000-02-11  Adventure           G
# 3                 Mission to Mars   2000-03-10  Adventure          PG
# 4                   High Fidelity   2000-03-31     Comedy           R
# ..                            ...          ...        ...         ...
# 253      The Light Between Oceans   2016-09-02      Drama       PG-13
# 254                Queen of Katwe   2016-09-23      Drama          PG
# 255                Doctor Strange   2016-11-04  Adventure       PG-13
# 256                         Moana   2016-11-23  Adventure          PG
# 257  Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  Year
# 0       60507228                  94852354  2000
# ...

# %%
df['Year'].max()
# Out:
# 2016

# %%
df['genre'].unique()
# Out:
# array(['Musical', 'Comedy', 'Adventure', 'Romantic Comedy', 'Western',
#        'Action', 'Drama', 'Thriller/Suspense', nan, 'Black Comedy',
#        'Documentary', 'Horror', 'Concert/Performance'], dtype=object)

# %%
df1 = df.groupby(['genre', 'Year'])['total_gross'].sum().reset_index()

df1
# Out:
#                  genre  Year  total_gross
# 0               Action  2000    101643008
# 1               Action  2001    228363017
# 2               Action  2002     73218998
# 3               Action  2004     74541707
# 4               Action  2006     55011732
# ..                 ...   ...          ...
# 99   Thriller/Suspense  2016     27569558
# 100            Western  2000     56932305
# 101            Western  2003     58331254
# 102            Western  2004     89693093
# 103            Western  2013     89302115
#
# [104 rows x 3 columns]

# %%
df2 = df1[(df1['genre'] == 'Musical') & (df1['Year'] == 2000)]['total_gross'].sum()
df2
# Out:
# 69610858

# %%
df3 = df1['total_gross'].sum()
df3
# Out:
# 24659185823

# %%
df4 = (df2 / df3) * 100
df4
# Out:
# 0.2822917938153209

# %%
g = df[(df['mpaa_rating'] == 'G') & (df['Year'] == 2001)]['mpaa_rating'].count()
p_g = df[(df['mpaa_rating'] == 'PG') & (df['Year'] == 2001)]['mpaa_rating'].count()
p_g13= df[(df['mpaa_rating'] == 'PG-13') & (df['Year'] == 2001)]['mpaa_rating'].count()
r= df[(df['mpaa_rating'] == 'R') & (df['Year'] == 2001)]['mpaa_rating'].count()
nr= df[(df['mpaa_rating'] == 'Not Rated') & (df['Year'] == 2001)]['mpaa_rating'].count()

print(g, p_g, p_g13, r, nr)
# Out:
# 3 2 7 2 0

# %%
total_rated = g + p_g + p_g13 + r + nr
total_rated
# Out:
# 14

# %%
g_per = (g / total_rated) * 100
g_per
# Out:
# 21.428571428571427
